# %%
import pandas as pd

# %%
drinks = pd.read_csv('https://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
drinks.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.sum()
# Out:
# continent
# Africa           3258
# Asia             1630
# Europe           8720
# North America    3345
# Oceania          1435
# South America    2101
# Name: beer_servings, dtype: int64

# %%
#drinks[drinks.continent=='Africa']

# %%
drinks[drinks.continent=='Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
drinks.groupby('continent').spirit_servings.agg(['count', 'min', 'max'])
# Out:
#                count  min  max
# continent
# Africa            53    0  152
# Asia              44    0  326
# Europe            45    0  373
# North America     23   68  438
# Oceania           16    0  254
# South America     12   25  302

# %%
drinks.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').mean().plot(kind='bar')

# %%
drinks[(drinks.beer_servings > 6) & (drinks.continent=='Europe')]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
#for or
drinks[(drinks.beer_servings > 6) | (drinks.continent=='Europe')]
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# ...
